# %%
import os, sys
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

DOSSIER = r'C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4'
sys.path.insert(0, DOSSIER)

for mod in ['env', 'model', 'train', 'preprocess']:
    if mod in sys.modules:
        del sys.modules[mod]

from train import train
print("Prêt")

# %%
from train import train

model_n10, history_n10 = train(
    n_clients       = 10,
    n_vehicles      = None,   # → K=3 automatique
    n_starts        = None,   # → 10 rollouts POMO
    n_epochs        = 200,
    steps_per_epoch = 50,
    accumulation    = 8,
    lr              = 1e-4,
    lr_decay_every  = 50,
    lr_decay_gamma  = 0.5,
    entropy_coeff   = 0.01,
    save_every      = 10,
    save_dir        = r'checkpoints_n10',
)
