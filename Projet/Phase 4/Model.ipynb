# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
print("OK")
# Out:
# OK

# %%
import sys
for mod in ['env', 'model', 'train', 'preprocess']:
    if mod in sys.modules:
        del sys.modules[mod]

sys.path.insert(0, r'C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4')
from train import train

model, history = train(
    n_clients       = 20,
    n_vehicles      = 3,
    n_epochs        = 100,
    steps_per_epoch = 200,
    lr              = 1e-4,
    entropy_coeff   = 0.01,
    save_every      = 10,
)
# Out:
# ============================================================
#   Entraînement VRPTW — Kool adapté multi-véhicules
# ============================================================
#   Device        : cuda
#   Paramètres    : 692,736
#   n_clients     : 20  |  n_vehicles : 3
#   Epochs        : 100 × 200 steps  |  lr : 0.0001
#   entropy_coeff : 0.01
# ============================================================
#
#   Epoch   1/100  sample= 1279.3  greedy= 1193.7  gap= +7.2%  loss=  -1897.6  31.4s
#   Epoch   2/100  sample= 1582.3  greedy= 1233.1  gap=+28.3%  loss=  -7733.7  27.1s
#   Epoch   3/100  sample= 1347.2  greedy= 1150.1  gap=+17.1%  loss=  -4325.6  30.8s
#   Epoch   4/100  sample= 1179.0  greedy= 1121.4  gap= +5.1%  loss=  -1195.8  32.5s
#   Epoch   5/100  sample= 1272.6  greedy= 1159.3  gap= +9.8%  loss=  -2490.8  31.4s
#   Epoch   6/100  sample= 1224.1  greedy= 1138.0  gap= +7.6%  loss=  -1763.0  32.4s
#   Epoch   7/100  sample= 1542.1  greedy= 1262.8  gap=+22.1%  loss=  -6669.2  28.0s
#   Epoch   8/100  sample= 1858.5  greedy= 1847.3  gap= +0.6%  loss=    323.1  22.3s
#   Epoch   9/100  sample= 1835.4  greedy= 1790.7  gap= +2.5%  loss=   -293.1  22.0s
#   Epoch  10/100  sample= 1853.1  greedy= 1786.0  gap= +3.8%  loss=   -861.2  16.6s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0010.pt
#   Epoch  11/100  sample= 1828.7  greedy= 1821.0  gap= +0.4%  loss=    491.3  20.5s
#   Epoch  12/100  sample= 1648.0  greedy= 1299.9  gap=+26.8%  loss=  -7250.2  24.2s
#   Epoch  13/100  sample= 1591.7  greedy= 1207.9  gap=+31.8%  loss=  -8798.3  25.2s
#   Epoch  14/100  sample= 1638.9  greedy= 1231.4  gap=+33.1%  loss=  -9180.7  24.8s
#   Epoch  15/100  sample= 1393.7  greedy= 1171.1  gap=+19.0%  loss=  -5118.2  27.2s
#   Epoch  16/100  sample= 1665.7  greedy= 1209.4  gap=+37.7%  loss= -10197.2  24.0s
#   Epoch  17/100  sample= 1408.0  greedy= 1151.8  gap=+22.2%  loss=  -5808.0  27.5s
#   Epoch  18/100  sample= 1689.5  greedy= 1147.5  gap=+47.2%  loss= -12436.1  24.1s
#   Epoch  19/100  sample= 1698.3  greedy= 1202.0  gap=+41.3%  loss= -11469.2  25.4s
#   Epoch  20/100  sample= 1541.4  greedy= 1138.4  gap=+35.4%  loss=  -9603.8  26.2s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0020.pt
#   Epoch  21/100  sample= 1405.9  greedy= 1120.1  gap=+25.5%  loss=  -7196.4  27.7s
#   Epoch  22/100  sample= 1357.1  greedy= 1147.0  gap=+18.3%  loss=  -5334.6  28.5s
#   Epoch  23/100  sample= 1336.4  greedy= 1123.1  gap=+19.0%  loss=  -5268.1  28.3s
#   Epoch  24/100  sample= 1280.8  greedy= 1143.6  gap=+12.0%  loss=  -3264.4  29.8s
#   Epoch  25/100  sample= 1284.6  greedy= 1140.1  gap=+12.7%  loss=  -3453.2  29.2s
#   Epoch  26/100  sample= 1769.3  greedy= 1119.5  gap=+58.0%  loss= -14714.2  23.4s
#   Epoch  27/100  sample= 1821.2  greedy= 1176.6  gap=+54.8%  loss= -14223.8  23.0s
#   Epoch  28/100  sample= 1809.2  greedy= 1142.3  gap=+58.4%  loss= -14689.7  23.6s
#   Epoch  29/100  sample= 1787.8  greedy= 1235.4  gap=+44.7%  loss= -12553.2  23.1s
#   Epoch  30/100  sample= 1551.3  greedy= 1160.0  gap=+33.7%  loss=  -9502.2  25.7s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0030.pt
#   Epoch  31/100  sample= 1278.7  greedy= 1179.2  gap= +8.4%  loss=  -2262.5  28.6s
#   Epoch  32/100  sample= 1278.6  greedy= 1160.9  gap=+10.1%  loss=  -2730.4  29.2s
#   Epoch  33/100  sample= 1671.6  greedy= 1124.0  gap=+48.7%  loss= -11807.6  24.9s
#   Epoch  34/100  sample= 1567.6  greedy= 1151.5  gap=+36.1%  loss= -10275.6  25.4s
#   Epoch  35/100  sample= 1500.9  greedy= 1198.4  gap=+25.2%  loss=  -7217.7  26.4s
#   Epoch  36/100  sample= 1487.2  greedy= 1129.7  gap=+31.6%  loss=  -8574.6  26.8s
#   Epoch  37/100  sample= 1219.2  greedy= 1122.2  gap= +8.6%  loss=  -2517.2  29.8s
#   Epoch  38/100  sample= 1250.8  greedy= 1145.3  gap= +9.2%  loss=  -2336.4  29.5s
#   Epoch  39/100  sample= 1207.2  greedy= 1128.4  gap= +7.0%  loss=  -1831.1  30.0s
#   Epoch  40/100  sample= 1164.9  greedy= 1120.1  gap= +4.0%  loss=  -1018.8  30.5s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0040.pt
#   Epoch  41/100  sample= 1314.7  greedy= 1132.5  gap=+16.1%  loss=  -4786.1  28.8s
#   Epoch  42/100  sample= 1224.5  greedy= 1120.2  gap= +9.3%  loss=  -2693.8  29.7s
#   Epoch  43/100  sample= 1178.2  greedy= 1128.1  gap= +4.4%  loss=   -925.3  30.5s
#   Epoch  44/100  sample= 1382.2  greedy= 1157.1  gap=+19.5%  loss=  -5700.4  28.2s
#   Epoch  45/100  sample= 1192.9  greedy= 1122.7  gap= +6.3%  loss=  -1621.9  30.5s
#   Epoch  46/100  sample= 1155.4  greedy= 1120.8  gap= +3.1%  loss=   -708.5  30.5s
#   Epoch  47/100  sample= 1176.8  greedy= 1126.4  gap= +4.5%  loss=   -979.4  30.3s
#   Epoch  48/100  sample= 1150.8  greedy= 1122.2  gap= +2.6%  loss=   -564.8  30.9s
#   Epoch  49/100  sample= 1145.9  greedy= 1116.8  gap= +2.6%  loss=   -655.6  31.0s
#   Epoch  50/100  sample= 1175.6  greedy= 1117.6  gap= +5.2%  loss=  -1075.3  30.6s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0050.pt
#   Epoch  51/100  sample= 1169.8  greedy= 1115.5  gap= +4.9%  loss=  -1106.8  30.6s
#   Epoch  52/100  sample= 1189.2  greedy= 1137.0  gap= +4.6%  loss=   -915.2  30.2s
#   Epoch  53/100  sample= 1261.6  greedy= 1119.5  gap=+12.7%  loss=  -3295.5  29.4s
#   Epoch  54/100  sample= 1225.4  greedy= 1120.1  gap= +9.4%  loss=  -2699.0  29.9s
#   Epoch  55/100  sample= 1128.7  greedy= 1116.9  gap= +1.1%  loss=   -295.2  29.3s
#   Epoch  56/100  sample= 1139.7  greedy= 1116.8  gap= +2.0%  loss=   -445.7  27.8s
#   Epoch  57/100  sample= 1314.0  greedy= 1135.9  gap=+15.7%  loss=  -3967.9  26.2s
#   Epoch  58/100  sample= 1355.5  greedy= 1118.7  gap=+21.2%  loss=  -5456.7  25.6s
#   Epoch  59/100  sample= 1248.9  greedy= 1121.3  gap=+11.4%  loss=  -2894.0  26.9s
#   Epoch  60/100  sample= 1839.1  greedy= 1739.9  gap= +5.7%  loss=  -1662.6  18.4s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0060.pt
#   Epoch  61/100  sample= 1850.2  greedy= 1848.3  gap= +0.1%  loss=    698.8  18.5s
#   Epoch  62/100  sample= 1851.3  greedy= 1847.4  gap= +0.2%  loss=    512.5  18.7s
#   Epoch  63/100  sample= 1853.0  greedy= 1863.8  gap= -0.6%  loss=    854.9  17.9s
#   Epoch  64/100  sample= 1837.3  greedy= 1846.1  gap= -0.5%  loss=    838.1  19.2s
#   Epoch  65/100  sample= 1824.4  greedy= 1843.7  gap= -1.0%  loss=    918.7  18.8s
#   Epoch  66/100  sample= 1860.5  greedy= 1842.3  gap= +1.0%  loss=    147.5  17.9s
#   Epoch  67/100  sample= 1824.7  greedy= 1848.6  gap= -1.3%  loss=   1155.6  18.9s
#   Epoch  68/100  sample= 1823.3  greedy= 1830.8  gap= -0.4%  loss=    689.8  18.0s
#   Epoch  69/100  sample= 1864.1  greedy= 1849.1  gap= +0.8%  loss=    294.1  18.7s
#   Epoch  70/100  sample= 1853.0  greedy= 1868.0  gap= -0.8%  loss=    809.9  18.8s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0070.pt
#   Epoch  71/100  sample= 1862.2  greedy= 1839.4  gap= +1.2%  loss=    109.8  17.5s
#   Epoch  72/100  sample= 1848.7  greedy= 1857.0  gap= -0.4%  loss=    740.2  19.1s
#   Epoch  73/100  sample= 1838.8  greedy= 1817.2  gap= +1.2%  loss=    -72.0  17.9s
#   Epoch  74/100  sample= 1861.3  greedy= 1834.3  gap= +1.5%  loss=    195.4  18.1s
#   Epoch  75/100  sample= 1830.9  greedy= 1812.3  gap= +1.0%  loss=    323.8  18.3s
#   Epoch  76/100  sample= 1844.6  greedy= 1847.3  gap= -0.1%  loss=    626.4  17.7s
#   Epoch  77/100  sample= 1831.1  greedy= 1841.4  gap= -0.6%  loss=    745.4  18.4s
#   Epoch  78/100  sample= 1849.9  greedy= 1864.7  gap= -0.8%  loss=   1030.8  17.7s
#   Epoch  79/100  sample= 1848.5  greedy= 1835.2  gap= +0.7%  loss=    460.7  18.5s
#   Epoch  80/100  sample= 1837.7  greedy= 1804.2  gap= +1.9%  loss=    -67.9  18.8s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0080.pt
#   Epoch  81/100  sample= 1830.7  greedy= 1835.6  gap= -0.3%  loss=    703.3  18.4s
#   Epoch  82/100  sample= 1856.0  greedy= 1828.7  gap= +1.5%  loss=   -135.9  19.1s
#   Epoch  83/100  sample= 1862.8  greedy= 1869.8  gap= -0.4%  loss=    693.7  19.4s
#   Epoch  84/100  sample= 1846.7  greedy= 1829.4  gap= +0.9%  loss=    323.1  18.0s
#   Epoch  85/100  sample= 1848.7  greedy= 1823.6  gap= +1.4%  loss=     11.3  18.6s
#   Epoch  86/100  sample= 1888.7  greedy= 1855.8  gap= +1.8%  loss=   -195.5  17.5s
#   Epoch  87/100  sample= 1845.2  greedy= 1832.1  gap= +0.7%  loss=    361.0  18.8s
#   Epoch  88/100  sample= 1871.9  greedy= 1848.6  gap= +1.3%  loss=     51.1  18.5s
#   Epoch  89/100  sample= 1859.2  greedy= 1843.1  gap= +0.9%  loss=    204.4  18.3s
#   Epoch  90/100  sample= 1858.2  greedy= 1830.8  gap= +1.5%  loss=    -16.3  18.3s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0090.pt
#   Epoch  91/100  sample= 1824.9  greedy= 1834.7  gap= -0.5%  loss=   1115.7  18.2s
#   Epoch  92/100  sample= 1852.0  greedy= 1849.7  gap= +0.1%  loss=    558.1  18.4s
#   Epoch  93/100  sample= 1840.4  greedy= 1857.6  gap= -0.9%  loss=   1022.2  18.4s
#   Epoch  94/100  sample= 1866.2  greedy= 1845.5  gap= +1.1%  loss=    245.3  18.1s
#   Epoch  95/100  sample= 1821.4  greedy= 1815.3  gap= +0.3%  loss=    315.0  18.5s
#   Epoch  96/100  sample= 1848.9  greedy= 1853.9  gap= -0.3%  loss=    840.7  18.0s
#   Epoch  97/100  sample= 1843.0  greedy= 1832.0  gap= +0.6%  loss=    516.0  18.0s
#   Epoch  98/100  sample= 1877.8  greedy= 1864.6  gap= +0.7%  loss=    339.3  18.3s
#   Epoch  99/100  sample= 1840.7  greedy= 1829.6  gap= +0.6%  loss=    487.0  18.4s
#   Epoch 100/100  sample= 1856.6  greedy= 1857.4  gap= -0.0%  loss=    611.0  18.9s
#   → checkpoint : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\checkpoint_epoch_0100.pt
#
#   Terminé — modèle sauvegardé : C:\Users\schen\Documents\CESI\RechercheOP\RechercheOp\Projet\Phase 4\checkpoints\model_final.pt
